# %%
# Importamos las librerías necesarias
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
raw_data = pd.read_csv("../data/Loan_training_set_1_4.csv", skiprows = 1)
raw_data
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                                       id  member_id  \
# 0                                              112435993        NaN
# 1                                              112290210        NaN
# 2                                              112436985        NaN
# 3                                              112439006        NaN
# 4                                              112438929        NaN
# ...                                                  ...        ...
# 105448                                         102628603        NaN
# 105449                                         102196576        NaN
# 105450                                          99799684        NaN
# ...

# %%
raw_data.tail()
# Out:
#                                                       id  member_id  \
# 105448                                         102628603        NaN
# 105449                                         102196576        NaN
# 105450                                          99799684        NaN
# 105451  Total amount funded in policy code 1: 1538432075        NaN
# 105452   Total amount funded in policy code 2: 608903141        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 105448    10050.0      10050.0          10050.0   36 months   16.99%
# 105449     6000.0       6000.0           6000.0   36 months   11.44%
# 105450    30000.0      30000.0          30000.0   60 months   25.49%
# 105451        NaN          NaN              NaN         NaN      NaN
# 105452        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade  ... hardship_payoff_balance_amount  \
# ...

# %%
raw_data[-raw_data.id.str.contains('Total amount funded', regex = False)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-97ee51cf16b7> in <module>
# ----> 1 raw_data[-raw_data.id.str.contains('Total amount funded', regex = False)]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2788
#    2789         # Do we have a (boolean) 1d indexer?
# -> 2790         if com.is_bool_indexer(key):
#    2791             return self._getitem_bool_array(key)
#    2792
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     134                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     135                 if isna(key).any():
# --> 136                     raise ValueError(na_msg)
#     137                 return False
#     138             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
raw_data.id.astype(str)
# Out:
# 0                                                112435993
# 1                                                112290210
# 2                                                112436985
# 3                                                112439006
# 4                                                112438929
#                                 ...
# 105448                                           102628603
# 105449                                           102196576
# 105450                                            99799684
# 105451    Total amount funded in policy code 1: 1538432075
# 105452     Total amount funded in policy code 2: 608903141
# Name: id, Length: 105453, dtype: object

# %%
raw_data.id.str.contains('Total amount funded', regex = False)
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 105448    False
# 105449    False
# 105450    False
# 105451     True
# 105452     True
# Name: id, Length: 105453, dtype: object

# %%
data2 = raw_data[raw_data.loan_status != 'Current']
data2
# Out:
#                                                       id  loan_amnt  \
# 8                                              112038251    11575.0
# 10                                             112149045     7200.0
# 24                                             112052261     7500.0
# 42                                             111999259    10000.0
# 91                                             111808508    14000.0
# ...                                                  ...        ...
# 105440                                         102436962     1000.0
# 105443                                         102395624    35000.0
# 105450                                          99799684    30000.0
# 105451  Total amount funded in policy code 1: 1538432075        NaN
# 105452   Total amount funded in policy code 2: 608903141        NaN
#
#         funded_amnt  funded_amnt_inv        term int_rate  installment grade  \
# ...

# %%
def filtrado(x):
    remove = set()
    na_total = x.isnull().sum()
    for i in na_total.index:
        if (na_total[i]>50000):
            remove.add(i)
    for i in remove:
        x.drop(i, axis=1, inplace=True)

# %%
filtrado(raw_data)

# %%
raw_data.chargeoff_within_12_mths.value_counts()
# Out:
# 0.0    104565
# 1.0       821
# 2.0        50
# 3.0        12
# 4.0         3
# Name: chargeoff_within_12_mths, dtype: int64

# %%
raw_data.collection_recovery_fee.mean()
# Out:
# 0.16829039838392046

# %%
raw_data.delinq_2yrs.value_counts()
# Out:
# 0.0     83373
# 1.0     14393
# 2.0      4363
# 3.0      1659
# 4.0       690
# 5.0       371
# 6.0       210
# 7.0       132
# 8.0        86
# 9.0        60
# 11.0       32
# 10.0       28
# 12.0       20
# 13.0       14
# 14.0        6
# 20.0        3
# 18.0        3
# 16.0        2
# 25.0        1
# 15.0        1
# 21.0        1
# 19.0        1
# 17.0        1
# 42.0        1
# Name: delinq_2yrs, dtype: int64

# %%
raw_data.earliest_cr_line ####
raw_data.emp_title  ###
raw_data.issue_d
raw_data.policy_code
raw_data.pymnt_plan
raw_data.recoveries # ???
raw_data.title
raw_data.url
verification_status # ? - Verificado por LC o no
# Out:
# 0                       NaN
# 1                   teacher
# 2              Front Office
# 3                   Manager
# 4                 Paramedic
#                 ...
# 105448      Sales Associate
# 105449        Contact input
# 105450    Assistant Manager
# 105451                  NaN
# 105452                  NaN
# Name: emp_title, Length: 105453, dtype: object

# %%
raw_data.loan_status.value_counts()
# Out:
# Current               92141
# Fully Paid             9043
# Late (31-120 days)     1895
# In Grace Period         923
# Charged Off             881
# Late (16-30 days)       567
# Default                   1
# Name: loan_status, dtype: int64

# %%
# QUITAR ALGUNAS CATEGORIAS
data2.home_ownership.value_counts()
# Out:
# MORTGAGE    6856
# RENT        4778
# OWN         1675
# ANY            1
# Name: home_ownership, dtype: int64

# %%
raw_data.hardship_flag.value_counts()
# Out:
# N    105421
# Y        30
# Name: hardship_flag, dtype: int64

# %%
data2.application_type.value_counts()
# Out:
# Individual    12619
# Joint App       691
# Name: application_type, dtype: int64

# %%
types = data2.dtypes
types = pd.DataFrame(types)

# %%
objects = types[types[0] == "object"]
objects
# Out:
#                            0
# id                    object
# term                  object
# int_rate              object
# grade                 object
# sub_grade             object
# emp_title             object
# emp_length            object
# home_ownership        object
# verification_status   object
# issue_d               object
# loan_status           object
# pymnt_plan            object
# url                   object
# purpose               object
# title                 object
# zip_code              object
# addr_state            object
# earliest_cr_line      object
# revol_util            object
# initial_list_status   object
# last_pymnt_d          object
# next_pymnt_d          object
# last_credit_pull_d    object
# application_type      object
# hardship_flag         object
# disbursement_method   object
# debt_settlement_flag  object

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13312 entries, 8 to 105452
# Columns: 108 entries, id to debt_settlement_flag
# dtypes: float64(81), object(27)
# memory usage: 11.1+ MB

# %%
data.corr
# Out:
# <bound method DataFrame.corr of                                                       id  loan_amnt  \
# 8                                              112038251    11575.0
# 10                                             112149045     7200.0
# 24                                             112052261     7500.0
# 42                                             111999259    10000.0
# 91                                             111808508    14000.0
# ...                                                  ...        ...
# 105440                                         102436962     1000.0
# 105443                                         102395624    35000.0
# 105450                                          99799684    30000.0
# 105451  Total amount funded in policy code 1: 1538432075        NaN
# 105452   Total amount funded in policy code 2: 608903141        NaN
#
#         funded_amnt  funded_amnt_inv        term int_rate  installment grade  \
# ...

# %%
raw_data
# Out:
#                                                       id  loan_amnt  \
# 0                                              112435993     2300.0
# 1                                              112290210    16000.0
# 2                                              112436985     6025.0
# 3                                              112439006    20400.0
# 4                                              112438929    13000.0
# ...                                                  ...        ...
# 105448                                         102628603    10050.0
# 105449                                         102196576     6000.0
# 105450                                          99799684    30000.0
# 105451  Total amount funded in policy code 1: 1538432075        NaN
# 105452   Total amount funded in policy code 2: 608903141        NaN
#
#         funded_amnt  funded_amnt_inv        term int_rate  installment grade  \
# ...
